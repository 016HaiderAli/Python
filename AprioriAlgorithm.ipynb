# %% [markdown]
# **Apriori Algorithm**

# %%
import numpy as np
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Loading the Data
data = pd.read_excel('/content/drive/MyDrive/Python/Apriori Algorithm/Online Retail.xlsx')
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
data.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
data.Country.unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %% [markdown]
# **Cleansing the Data**

# %%
# Stripping extra spaces in the description
data['Description'] = data['Description'].str.strip()
  
# Dropping the rows without any invoice number
data.dropna(axis = 0, subset =['InvoiceNo'], inplace = True)
data['InvoiceNo'] = data['InvoiceNo'].astype('str')
  
# Dropping all transactions which were done on credit
data = data[~data['InvoiceNo'].str.contains('C')]

# %% [markdown]
# **Splitting the data according to the region of transaction**

# %%
# Transactions done in France
basket_France = (data[data['Country'] =="France"]
		.groupby(['InvoiceNo', 'Description'])['Quantity']
		.sum().unstack().reset_index().fillna(0)
		.set_index('InvoiceNo'))

# Transactions done in the United Kingdom
basket_UK = (data[data['Country'] =="United Kingdom"]
		.groupby(['InvoiceNo', 'Description'])['Quantity']
		.sum().unstack().reset_index().fillna(0)
		.set_index('InvoiceNo'))

# Transactions done in Portugal
basket_Por = (data[data['Country'] =="Portugal"]
		.groupby(['InvoiceNo', 'Description'])['Quantity']
		.sum().unstack().reset_index().fillna(0)
		.set_index('InvoiceNo'))

basket_Sweden = (data[data['Country'] =="Sweden"]
		.groupby(['InvoiceNo', 'Description'])['Quantity']
		.sum().unstack().reset_index().fillna(0)
		.set_index('InvoiceNo'))

# %% [markdown]
# **Hot encoding the Data**

# %%
# Defining the hot encoding function to make the data suitable
# for the concerned libraries
def hot_encode(x):
	if(x<= 0):
		return 0
	if(x>= 1):
		return 1

# Encoding the datasets
basket_encoded = basket_France.applymap(hot_encode)
basket_France = basket_encoded

basket_encoded = basket_UK.applymap(hot_encode)
basket_UK = basket_encoded

basket_encoded = basket_Por.applymap(hot_encode)
basket_Por = basket_encoded

basket_encoded = basket_Sweden.applymap(hot_encode)
basket_Sweden = basket_encoded

# %% [markdown]
# **Building the models and analyzing the results**

# %%
# Building the model
frq_items = apriori(basket_France, min_support = 0.05, use_colnames = True)

# Collecting the inferred rules in a dataframe
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
rules
# Out:
#                                            antecedents  \
# 45                        (JUMBO BAG WOODLAND ANIMALS)
# 260  (RED TOADSTOOL LED NIGHT LIGHT, PLASTERS IN TI...
# 272  (RED TOADSTOOL LED NIGHT LIGHT, PLASTERS IN TI...
# 302  (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETRO...
# 301  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...
# ..                                                 ...
# 36                                           (POSTAGE)
# 27                                           (POSTAGE)
# 96                                           (POSTAGE)
# 226                                          (POSTAGE)
# 213                                          (POSTAGE)
#
#                                            consequents  antecedent support  \
# 45                                           (POSTAGE)            0.076531
# 260                                          (POSTAGE)            0.051020
# 272                                          (POSTAGE)            0.053571
# 302                    (SET/6 RED SPOTTY PAPER PLATES)            0.102041
# 301                      (SET/6 RED SPOTTY PAPER CUPS)            0.102041
# ..                                                 ...                 ...
# 36                            (JAM MAKING SET PRINTED)            0.765306
# 27                   (CIRCUS PARADE CHILDRENS EGG CUP)            0.765306
# 96                                     (PARTY BUNTING)            0.765306
# 226      (LUNCH BAG WOODLAND, LUNCH BAG RED RETROSPOT)            0.765306
# 213  (LUNCH BAG APPLE DESIGN, LUNCH BAG SPACEBOY DE...            0.765306
#
#      consequent support   support  confidence      lift  leverage  conviction
# 45             0.765306  0.076531    1.000000  1.306667  0.017961         inf
# 260            0.765306  0.051020    1.000000  1.306667  0.011974         inf
# 272            0.765306  0.053571    1.000000  1.306667  0.012573         inf
# 302            0.127551  0.099490    0.975000  7.644000  0.086474   34.897959
# 301            0.137755  0.099490    0.975000  7.077778  0.085433   34.489796
# ..                  ...       ...         ...       ...       ...         ...
# 36             0.053571  0.051020    0.066667  1.244444  0.010022    1.014031
# 27             0.056122  0.051020    0.066667  1.187879  0.008070    1.011297
# 96             0.056122  0.051020    0.066667  1.187879  0.008070    1.011297
# 226            0.056122  0.051020    0.066667  1.187879  0.008070    1.011297
# 213            0.063776  0.051020    0.066667  1.045333  0.002213    1.003098
#
# [348 rows x 9 columns]

# %%
#B) United Kingdom
frq_items = apriori(basket_UK, min_support = 0.01, use_colnames = True)
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
rules
# Out:
#                                        antecedents  \
# 117           (BEADED CRYSTAL HEART PINK ON STICK)
# 2020  (JAM MAKING SET PRINTED, SUKI  SHOULDER BAG)
# 2296         (HERB MARKER THYME, HERB MARKER MINT)
# 2300   (HERB MARKER ROSEMARY, HERB MARKER PARSLEY)
# 2302      (HERB MARKER PARSLEY, HERB MARKER THYME)
# ...                                            ...
# 1720          (WHITE HANGING HEART T-LIGHT HOLDER)
# 440           (WHITE HANGING HEART T-LIGHT HOLDER)
# 294           (WHITE HANGING HEART T-LIGHT HOLDER)
# 1560          (WHITE HANGING HEART T-LIGHT HOLDER)
# 1742          (WHITE HANGING HEART T-LIGHT HOLDER)
#
#                                consequents  antecedent support  \
# 117                       (DOTCOM POSTAGE)            0.011036
# 2020                      (DOTCOM POSTAGE)            0.011625
# 2296                (HERB MARKER ROSEMARY)            0.010714
# 2300                   (HERB MARKER THYME)            0.011089
# 2302                (HERB MARKER ROSEMARY)            0.011089
# ...                                    ...                 ...
# 1720         (SMALL WHITE HEART OF WICKER)            0.116034
# 440    (GARDENERS KNEELING PAD CUP OF TEA)            0.116034
# 294            (COOK WITH WINE METAL SIGN)            0.116034
# 1560    (POTTERING IN THE SHED METAL SIGN)            0.116034
# 1742  (WOOD 2 DRAWER CABINET WHITE FINISH)            0.116034
#
#       consequent support   support  confidence       lift  leverage  \
# 117             0.037928  0.010768    0.975728  25.725872  0.010349
# 2020            0.037928  0.011196    0.963134  25.393807  0.010755
# 2296            0.012375  0.010232    0.955000  77.173095  0.010099
# 2300            0.012321  0.010553    0.951691  77.240055  0.010417
# 2302            0.012375  0.010553    0.951691  76.905682  0.010416
# ...                  ...       ...         ...        ...       ...
# 1720            0.032839  0.010125    0.087258   2.657158  0.006314
# 440             0.040178  0.010125    0.087258   2.171784  0.005463
# 294             0.036910  0.010071    0.086796   2.351553  0.005788
# 1560            0.028553  0.010018    0.086334   3.023643  0.006705
# 1742            0.028607  0.010018    0.086334   3.017980  0.006698
#
#       conviction
# 117    39.637371
# 2020   26.096206
# 2296   21.947227
# 2300   20.444951
# 2302   20.443842
# ...          ...
# 1720    1.059621
# 440     1.051581
# 294     1.054627
# 1560    1.063241
# 1742    1.063182
#
# [3760 rows x 9 columns]

# %%
frq_items = apriori(basket_Por, min_support = 0.05, use_colnames = True)
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
rules
# Out:
#                              antecedents  \
# 1170  (SET 12 COLOUR PENCILS DOLLY GIRL)
# 1171    (SET 12 COLOUR PENCILS SPACEBOY)
# 1172  (SET 12 COLOUR PENCILS DOLLY GIRL)
# 1173  (SET OF 4 KNICK KNACK TINS LONDON)
# 1174  (SET 12 COLOUR PENCILS DOLLY GIRL)
# ...                                  ...
# 1057                           (POSTAGE)
# 1059                           (POSTAGE)
# 1066                           (POSTAGE)
# 1070                           (POSTAGE)
# 1209                           (POSTAGE)
#
#                                             consequents  antecedent support  \
# 1170                   (SET 12 COLOUR PENCILS SPACEBOY)            0.051724
# 1171                 (SET 12 COLOUR PENCILS DOLLY GIRL)            0.051724
# 1172                 (SET OF 4 KNICK KNACK TINS LONDON)            0.051724
# 1173                 (SET 12 COLOUR PENCILS DOLLY GIRL)            0.051724
# 1174                (SET OF 4 KNICK KNACK TINS POPPIES)            0.051724
# ...                                                 ...                 ...
# 1057                         (REGENCY CAKESTAND 3 TIER)            0.517241
# 1059                 (RETROSPOT HEART HOT WATER BOTTLE)            0.517241
# 1066                 (SET OF 3 CAKE TINS PANTRY DESIGN)            0.517241
# 1070                  (SET OF 36 TEATIME PAPER DOILIES)            0.517241
# 1209  (4 TRADITIONAL SPINNING TOPS, CHARLOTTE BAG SU...            0.517241
#
#       consequent support   support  confidence       lift  leverage  \
# 1170            0.051724  0.051724         1.0  19.333333  0.049049
# 1171            0.051724  0.051724         1.0  19.333333  0.049049
# 1172            0.051724  0.051724         1.0  19.333333  0.049049
# 1173            0.051724  0.051724         1.0  19.333333  0.049049
# 1174            0.051724  0.051724         1.0  19.333333  0.049049
# ...                  ...       ...         ...        ...       ...
# 1057            0.086207  0.051724         0.1   1.160000  0.007134
# 1059            0.086207  0.051724         0.1   1.160000  0.007134
# 1066            0.086207  0.051724         0.1   1.160000  0.007134
# 1070            0.086207  0.051724         0.1   1.160000  0.007134
# 1209            0.086207  0.051724         0.1   1.160000  0.007134
#
#       conviction
# 1170         inf
# 1171         inf
# 1172         inf
# 1173         inf
# 1174         inf
# ...          ...
# 1057    1.015326
# 1059    1.015326
# 1066    1.015326
# 1070    1.015326
# 1209    1.015326
#
# [335164 rows x 9 columns]

# %%
frq_items = apriori(basket_Sweden, min_support = 0.05, use_colnames = True)
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
rules
# Out:
#                           antecedents  \
# 0       (PACK OF 72 SKULL CAKE CASES)
# 1       (12 PENCILS SMALL TUBE SKULL)
# 4      (ASSORTED BOTTLE TOP  MAGNETS)
# 5             (36 DOILIES DOLLY GIRL)
# 180    (CHILDRENS CUTLERY DOLLY GIRL)
# ...                               ...
# 25486                       (POSTAGE)
# 202                         (POSTAGE)
# 384                         (POSTAGE)
# 482                         (POSTAGE)
# 3571                        (POSTAGE)
#
#                                              consequents  antecedent support  \
# 0                          (12 PENCILS SMALL TUBE SKULL)            0.055556
# 1                          (PACK OF 72 SKULL CAKE CASES)            0.055556
# 4                                (36 DOILIES DOLLY GIRL)            0.055556
# 5                         (ASSORTED BOTTLE TOP  MAGNETS)            0.055556
# 180                    (CHILDRENS CUTLERY CIRCUS PARADE)            0.055556
# ...                                                  ...                 ...
# 25486  (CHILDRENS CUTLERY DOLLY GIRL, CHILDRENS CUTLE...            0.611111
# 202                           (CUPCAKE LACE PAPER SET 6)            0.611111
# 384                      (MINI PLAYING CARDS DOLLY GIRL)            0.611111
# 482                 (ROUND SNACK BOXES SET OF4 WOODLAND)            0.611111
# 3571   (ROUND SNACK BOXES SET OF4 WOODLAND, ROUND SNA...            0.611111
#
#        consequent support   support  confidence       lift  leverage  \
# 0                0.055556  0.055556    1.000000  18.000000  0.052469
# 1                0.055556  0.055556    1.000000  18.000000  0.052469
# 4                0.055556  0.055556    1.000000  18.000000  0.052469
# 5                0.055556  0.055556    1.000000  18.000000  0.052469
# 180              0.055556  0.055556    1.000000  18.000000  0.052469
# ...                   ...       ...         ...        ...       ...
# 25486            0.055556  0.055556    0.090909   1.636364  0.021605
# 202              0.083333  0.055556    0.090909   1.090909  0.004630
# 384              0.083333  0.055556    0.090909   1.090909  0.004630
# 482              0.083333  0.055556    0.090909   1.090909  0.004630
# 3571             0.083333  0.055556    0.090909   1.090909  0.004630
#
#        conviction
# 0             inf
# 1             inf
# 4             inf
# 5             inf
# 180           inf
# ...           ...
# 25486    1.038889
# 202      1.008333
# 384      1.008333
# 482      1.008333
# 3571     1.008333
#
# [104608 rows x 9 columns]
